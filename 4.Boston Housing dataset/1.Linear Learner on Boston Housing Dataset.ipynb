# %%
# Run this cell if you wan't to run locally on laptop
import boto3
region = boto3.Session().region_name

def resolve_sm_role():
    client = boto3.client('iam', region_name=region)
    response_roles = client.list_roles(
        PathPrefix='/',
        # Marker='string',
        MaxItems=999
    )
    for role in response_roles['Roles']:
        if role['RoleName'].startswith('AmazonSageMaker-ExecutionRole-'):
            #print('Resolved SageMaker IAM Role to: ' + str(role))
            return role['Arn']
    raise Exception('Could not resolve what should be the SageMaker role to be used')

role = resolve_sm_role()
print(role)
# Out:
# arn:aws:iam::603012210694:role/service-role/AmazonSageMaker-ExecutionRole-20210304T123661

# %% [markdown]
# ### Using the SageMaker SDK with built-in algorithms

# %% [markdown]
# ## 1.Preparing data
# In Book Example we manually downloaded csv from link below
#
# https://github.com/PacktPublishing/Learn-Amazon-SageMaker/blob/master/sdkv2/ch4/housing.csv
#
# But this dataset is also available in sklearn, so i'm just going to import it import it from there.

# %%
from sklearn.datasets import load_boston
from pandas import DataFrame
import pandas as pd
import numpy as np

boston = load_boston()
data = boston
df = DataFrame(np.concatenate((boston.data, boston.target.reshape(-1, 1)), axis=1), 
                            columns=np.concatenate((boston.feature_names, ["MEDV"])))

print("Rows and Columns :",df.shape)
display(df.head(2))
# Out:
# Rows and Columns : (506, 14)
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO      B  LSTAT  MEDV
# 0     15.3  396.9   4.98  24.0
# 1     17.8  396.9   9.14  21.6

# %% [markdown]
# 1. In book example we don't have Column name B, so we are going to drop it as well.

# %%
del df['B']
print("Rows and Columns :",df.shape)
display(df.head(2))
# Out:
# Rows and Columns : (506, 13)
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO  LSTAT  MEDV
# 0     15.3   4.98  24.0
# 1     17.8   9.14  21.6

# %% [markdown]
# Reading the algorithm documentation ( https://docs.aws.amazon.com/sagemaker/latest/dg/cdf-training.html )
# , we see that Amazon SageMaker requires that a CSV file doesn't have a header record and that the target
# variable is in the first column. Accordingly, we move the medv column to the front
# of the dataframe:

# %%
df = pd.concat([df['MEDV'],df.drop(['MEDV'], axis=1)],axis=1)
print("Rows and Columns :",df.shape)
display(df.head(2))
# Out:
# Rows and Columns : (506, 13)
#    MEDV     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO  LSTAT
# 0     15.3   4.98
# 1     17.8   9.14

# %% [markdown]
# Spliting dataframe into: 90% training, and 10% validation:

# %%
from sklearn.model_selection import train_test_split
training_dataset, validation_dataset = train_test_split(df, test_size=0.1)
print(training_dataset.shape)
print(validation_dataset.shape)
# Out:
# (455, 13)
# (51, 13)

# %% [markdown]
# We save these two splits to individual CSV files, without either an index or a header:

# %%
training_dataset.to_csv('training_dataset.csv', index=False, header=False)
validation_dataset.to_csv('validation_dataset.csv', index=False, header=False)

# %%
# lets check in our pc, you can skip this step
import os
print(os.listdir("."))

display(pd.read_csv('training_dataset.csv').head(2))
display(pd.read_csv('validation_dataset.csv').head(2))
# Out:
# ['.ipynb_checkpoints', '1.Linear Learner on Boston Housing Dataset.ipynb', '2.XGBoost on Boston Housing Dataset.ipynb', 'Boston_Housing Model.ipynb', 'housing.csv', 'Linear Learner on Boston Housing Dataset.ipynb', 'mnist old', 'training_dataset.csv', 'validation_dataset.csv', 'XGBoost on Boston Housing Dataset.ipynb']
#    24.0   0.00632  18.0  2.31  0.0  0.538  6.575   65.2    4.09   1.0  296.0  \
# 0  12.3   7.99248   0.0  18.1  0.0  0.700  5.520  100.0  1.5331  24.0  666.0
# 1   5.0  67.92080   0.0  18.1  0.0  0.693  5.683  100.0  1.4254  24.0  666.0
#
#    15.3   4.98
# 0  20.2  24.56
# 1  20.2  22.98
#    16.3  28.6558   0.0  18.1  0.0.1  0.597  5.155  100.0  1.5894  24.0  666.0  \
# 0  50.0  0.57834  20.0  3.97    0.0  0.575  8.297   67.0  2.4216   5.0  264.0
# 1  36.4  0.08664  45.0  3.44    0.0  0.437  7.178   26.3  6.4798   5.0  398.0
#
#    20.2  20.08
# 0  13.0   7.44
# 1  15.2   2.87

# %% [markdown]
# ## 2.Uploading data
# We now need to upload these two files to S3. We could use any bucket, and
# here we'll use the default bucket conveniently created by SageMaker in the region
# we're running in.

# %%
import sagemaker
#print(sagemaker.__version__)
sess = sagemaker.Session()
bucket = sess.default_bucket()

prefix = 'boston-housing'
training_data_path = sess.upload_data(path='training_dataset.csv', key_prefix=prefix + '/input/training')
validation_data_path = sess.upload_data(path='validation_dataset.csv', key_prefix=prefix + '/input/validation')

print(training_data_path)
print(validation_data_path)
# Out:
# s3://sagemaker-us-east-1-603012210694/boston-housing/input/training/training_dataset.csv
# s3://sagemaker-us-east-1-603012210694/boston-housing/input/validation/validation_dataset.csv

# %% [markdown]
# ## 3.Configuring a training job
# 1. Earlier in this chapter, we learned that SageMaker algorithms are packaged in
# Docker containers. Using boto3 and the image_uris.retrieve() API, we
# can easily find the name of the Linear Learner algorithm in the region
# we're running:

# %%
import boto3
from sagemaker import image_uris

region = boto3.Session().region_name    
container = image_uris.retrieve('linear-learner', region)
#print(container)

# %% [markdown]
# 2. Now that we know the name of the container, we can configure our training job
# with the Estimator object. In addition to the container name, we also pass the
# IAM role that SageMaker instances will use, the instance type and instance count
# to use for training, as well as the output location for the model. Estimator will
# generate a training job automatically, and we could also set our own prefix with the
# base_job_name parameter:

# %%
from sagemaker.estimator import Estimator
ll_estimator = Estimator(
                container,
                role=role,#sagemaker.get_execution_role(),
                instance_count=1,
                instance_type='ml.m4.xlarge',#'ml.m5.large',
                output_path='s3://{}/{}/output'.format(bucket,prefix))

# %% [markdown]
# 3. Next, we have to set hyperparameters. This step is possibly one of the most obscure
# and most difficult parts of any machine learning project.
# Let's look at the documentation, and see which hyperparameters are mandatory
# ( https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html) . As it turns out, there is only one: predictor_type . It defines the type of problem that Linear Learner is training on (regression,
# binary classification, or multiclass classification).
# Taking a deeper look, we see that the default value for mini_batch_size is 1000:
# this isn't going to work well with our 506-sample dataset, so let's set it to 32. We also
# learn that the normalize_data parameter is set to true by default, which makes
# it unnecessary to normalize data ourselves:

# %%
ll_estimator.set_hyperparameters(predictor_type='regressor', mini_batch_size=32)

# %% [markdown]
# 4. Now, let's define the data channels: a channel is a named source of data passed to
# a SageMaker estimator. All built-in algorithms need at least a train channel, and
# many also accept additional channels for validation and testing. Here, we have two
# channels, which both provide data in CSV format. The TrainingInput() API
# lets us define their location, their format, whether they are compressed, and so on:

# %%
training_data_channel   = sagemaker.TrainingInput(s3_data=training_data_path, content_type='text/csv')
validation_data_channel = sagemaker.TrainingInput(s3_data=validation_data_path, content_type='text/csv')

# %% [markdown]
# ## 4.Launching a training job
# 1. We simply pass a Python dictionary containing the two channels to the fit() API:

# %%
ll_data = {'train': training_data_channel, 'validation': validation_data_channel}
ll_estimator.fit(ll_data)
# Out:
# 2021-03-28 11:16:09 Starting - Starting the training job...
# 2021-03-28 11:16:32 Starting - Launching requested ML instancesProfilerReport-1616930168: InProgress
# ......
# 2021-03-28 11:17:52 Starting - Preparing the instances for training......
# 2021-03-28 11:18:52 Downloading - Downloading input data...
# 2021-03-28 11:19:33 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [03/28/2021 11:19:37 INFO 140028512040768] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [03/28/2021 11:19:37 INFO 140028512040768] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'predictor_type': 'regressor', 'mini_batch_size': '32'}
# [03/28/2021 11:19:37 INFO 140028512040768] Final configuration: {'mini_batch_size': '32', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [03/28/2021 11:19:37 WARNING 140028512040768] Loggers have already been setup.
# Process 1 is a worker.
# [03/28/2021 11:19:37 INFO 140028512040768] Using default worker.
# [03/28/2021 11:19:37 INFO 140028512040768] Checkpoint loading and saving are disabled.
# [03/28/2021 11:19:37 INFO 140028512040768] Create Store: local
# [03/28/2021 11:19:37 INFO 140028512040768] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f5a8ce68c90>
# [03/28/2021 11:19:37 INFO 140028512040768] Scaling model computed with parameters:
#  {'stdev_label':
# [8.909716]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [8.96790504e+00 2.24527073e+01 6.80071402e+00 2.37982437e-01
#  1.14026174e-01 6.84708655e-01 2.79439812e+01 1.99550200e+00
#  8.73375511e+00 1.69159897e+02 2.10772657e+00 7.19408274e+00]
# <NDArray 12 @cpu(0)>, 'mean_label':
# [22.117857]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [3.7897062e+00 1.0438617e+01 1.1270223e+01 6.0267858e-02 5.5507571e-01
#  6.2626138e+00 6.9186378e+01 3.7133236e+00 9.6718750e+00 4.1066293e+02
#  1.8533926e+01 1.2887923e+01]
# <NDArray 12 @cpu(0)>}
# [03/28/2021 11:19:37 INFO 140028512040768] nvidia-smi took: 0.025342464447021484 secs to identify 0 gpus
# [03/28/2021 11:19:37 INFO 140028512040768] Number of GPUs being used: 0
# #metrics {"StartTime": 1616930378.0134192, "EndTime": 1616930378.0134592, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 487.0, "count": 1, "min": 487, "max": 487}, "Total Batches Seen": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# #metrics {"StartTime": 1616930378.4688644, "EndTime": 1616930378.468925, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.7326710394450596, "count": 1, "min": 0.7326710394450596, "max": 0.7326710394450596}}}
#
# #metrics {"StartTime": 1616930378.469008, "EndTime": 1616930378.469022, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.819542720913887, "count": 1, "min": 0.819542720913887, "max": 0.819542720913887}}}
#
# #metrics {"StartTime": 1616930378.4690752, "EndTime": 1616930378.469092, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.8812744872910636, "count": 1, "min": 0.8812744872910636, "max": 0.8812744872910636}}}
#
# #metrics {"StartTime": 1616930378.4691737, "EndTime": 1616930378.4691935, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.8778090264116015, "count": 1, "min": 0.8778090264116015, "max": 0.8778090264116015}}}
#
# #metrics {"StartTime": 1616930378.4692516, "EndTime": 1616930378.4692683, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.8218790888786316, "count": 1, "min": 0.8218790888786316, "max": 0.8218790888786316}}}
#
# #metrics {"StartTime": 1616930378.4693341, "EndTime": 1616930378.469352, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.8686729744076729, "count": 1, "min": 0.8686729744076729, "max": 0.8686729744076729}}}
#
# #metrics {"StartTime": 1616930378.4694064, "EndTime": 1616930378.4694211, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.8028569934623582, "count": 1, "min": 0.8028569934623582, "max": 0.8028569934623582}}}
#
# #metrics {"StartTime": 1616930378.4694521, "EndTime": 1616930378.4694605, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.8012001014181546, "count": 1, "min": 0.8012001014181546, "max": 0.8012001014181546}}}
#
# #metrics {"StartTime": 1616930378.4694881, "EndTime": 1616930378.469496, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.7890513070992061, "count": 1, "min": 0.7890513070992061, "max": 0.7890513070992061}}}
#
# #metrics {"StartTime": 1616930378.4695542, "EndTime": 1616930378.4695702, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.6209337945495333, "count": 1, "min": 0.6209337945495333, "max": 0.6209337945495333}}}
#
# #metrics {"StartTime": 1616930378.4696302, "EndTime": 1616930378.4696443, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.9800633937120438, "count": 1, "min": 0.9800633937120438, "max": 0.9800633937120438}}}
#
# #metrics {"StartTime": 1616930378.4696958, "EndTime": 1616930378.4697125, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.8537306423698153, "count": 1, "min": 0.8537306423698153, "max": 0.8537306423698153}}}
#
# #metrics {"StartTime": 1616930378.4697685, "EndTime": 1616930378.4697847, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.8490920971546855, "count": 1, "min": 0.8490920971546855, "max": 0.8490920971546855}}}
#
# #metrics {"StartTime": 1616930378.4698398, "EndTime": 1616930378.4698555, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.8011752462812832, "count": 1, "min": 0.8011752462812832, "max": 0.8011752462812832}}}
#
# #metrics {"StartTime": 1616930378.4699118, "EndTime": 1616930378.469927, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.7954379543662071, "count": 1, "min": 0.7954379543662071, "max": 0.7954379543662071}}}
#
# #metrics {"StartTime": 1616930378.4699826, "EndTime": 1616930378.4699988, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.8256803378462791, "count": 1, "min": 0.8256803378462791, "max": 0.8256803378462791}}}
#
# #metrics {"StartTime": 1616930378.4700534, "EndTime": 1616930378.4700701, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.7685495508568627, "count": 1, "min": 0.7685495508568627, "max": 0.7685495508568627}}}
#
# #metrics {"StartTime": 1616930378.4701273, "EndTime": 1616930378.4701433, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.8870316424540111, "count": 1, "min": 0.8870316424540111, "max": 0.8870316424540111}}}
#
# #metrics {"StartTime": 1616930378.4701977, "EndTime": 1616930378.4702144, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.6993352110896792, "count": 1, "min": 0.6993352110896792, "max": 0.6993352110896792}}}
#
# #metrics {"StartTime": 1616930378.4702935, "EndTime": 1616930378.4703112, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.7749234863689968, "count": 1, "min": 0.7749234863689968, "max": 0.7749234863689968}}}
#
# #metrics {"StartTime": 1616930378.4703658, "EndTime": 1616930378.4703827, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.8058775184409959, "count": 1, "min": 0.8058775184409959, "max": 0.8058775184409959}}}
#
# #metrics {"StartTime": 1616930378.4704459, "EndTime": 1616930378.4704638, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.8306435532867908, "count": 1, "min": 0.8306435532867908, "max": 0.8306435532867908}}}
#
# #metrics {"StartTime": 1616930378.470519, "EndTime": 1616930378.470536, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.8249935986740249, "count": 1, "min": 0.8249935986740249, "max": 0.8249935986740249}}}
#
# #metrics {"StartTime": 1616930378.4705935, "EndTime": 1616930378.4706106, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.8096927558737141, "count": 1, "min": 0.8096927558737141, "max": 0.8096927558737141}}}
#
# #metrics {"StartTime": 1616930378.4706638, "EndTime": 1616930378.4706795, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9548453773771014, "count": 1, "min": 0.9548453773771014, "max": 0.9548453773771014}}}
#
# #metrics {"StartTime": 1616930378.470731, "EndTime": 1616930378.4707477, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 1.0336734439645494, "count": 1, "min": 1.0336734439645494, "max": 1.0336734439645494}}}
#
# #metrics {"StartTime": 1616930378.4708014, "EndTime": 1616930378.4708173, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9820947838681084, "count": 1, "min": 0.9820947838681084, "max": 0.9820947838681084}}}
#
# #metrics {"StartTime": 1616930378.4708729, "EndTime": 1616930378.4708893, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.0877107296671187, "count": 1, "min": 1.0877107296671187, "max": 1.0877107296671187}}}
#
# #metrics {"StartTime": 1616930378.4709496, "EndTime": 1616930378.4709663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.2953691141945975, "count": 1, "min": 1.2953691141945975, "max": 1.2953691141945975}}}
#
# #metrics {"StartTime": 1616930378.4710197, "EndTime": 1616930378.4710362, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.2495272670473372, "count": 1, "min": 1.2495272670473372, "max": 1.2495272670473372}}}
#
# #metrics {"StartTime": 1616930378.4710898, "EndTime": 1616930378.4711068, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.2799612070832933, "count": 1, "min": 1.2799612070832933, "max": 1.2799612070832933}}}
#
# #metrics {"StartTime": 1616930378.4711592, "EndTime": 1616930378.4711747, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.291518666914531, "count": 1, "min": 1.291518666914531, "max": 1.291518666914531}}}
#
# [03/28/2021 11:19:38 INFO 140028512040768] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.7326710394450596
# #metrics {"StartTime": 1616930378.542033, "EndTime": 1616930378.5421424, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 80.95998008578431, "count": 1, "min": 80.95998008578431, "max": 80.95998008578431}}}
#
# #metrics {"StartTime": 1616930378.5422616, "EndTime": 1616930378.5422804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 90.05432368259804, "count": 1, "min": 90.05432368259804, "max": 90.05432368259804}}}
#
# #metrics {"StartTime": 1616930378.5423439, "EndTime": 1616930378.5423615, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 98.55082912071079, "count": 1, "min": 98.55082912071079, "max": 98.55082912071079}}}
#
# #metrics {"StartTime": 1616930378.5424175, "EndTime": 1616930378.54243, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 95.39438285079657, "count": 1, "min": 95.39438285079657, "max": 95.39438285079657}}}
#
# #metrics {"StartTime": 1616930378.542626, "EndTime": 1616930378.542645, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 23.058641620710784, "count": 1, "min": 23.058641620710784, "max": 23.058641620710784}}}
#
# #metrics {"StartTime": 1616930378.5427034, "EndTime": 1616930378.5427203, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 24.581517836626837, "count": 1, "min": 24.581517836626837, "max": 24.581517836626837}}}
#
# #metrics {"StartTime": 1616930378.542784, "EndTime": 1616930378.5428019, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 23.460828594132966, "count": 1, "min": 23.460828594132966, "max": 23.460828594132966}}}
#
# #metrics {"StartTime": 1616930378.5428581, "EndTime": 1616930378.542877, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 21.979673497817096, "count": 1, "min": 21.979673497817096, "max": 21.979673497817096}}}
#
# #metrics {"StartTime": 1616930378.542942, "EndTime": 1616930378.5429616, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 89.87920783547794, "count": 1, "min": 89.87920783547794, "max": 89.87920783547794}}}
#
# #metrics {"StartTime": 1616930378.5430312, "EndTime": 1616930378.5430496, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 65.85077263327206, "count": 1, "min": 65.85077263327206, "max": 65.85077263327206}}}
#
# #metrics {"StartTime": 1616930378.5431154, "EndTime": 1616930378.5431342, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 100.73394895067402, "count": 1, "min": 100.73394895067402, "max": 100.73394895067402}}}
#
# #metrics {"StartTime": 1616930378.5432, "EndTime": 1616930378.5432184, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 102.49367149203431, "count": 1, "min": 102.49367149203431, "max": 102.49367149203431}}}
#
# #metrics {"StartTime": 1616930378.543288, "EndTime": 1616930378.5433056, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 21.748523786956188, "count": 1, "min": 21.748523786956188, "max": 21.748523786956188}}}
#
# #metrics {"StartTime": 1616930378.5433657, "EndTime": 1616930378.5433836, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 21.908100801355697, "count": 1, "min": 21.908100801355697, "max": 21.908100801355697}}}
#
# #metrics {"StartTime": 1616930378.54343, "EndTime": 1616930378.5434408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 21.69844803155637, "count": 1, "min": 21.69844803155637, "max": 21.69844803155637}}}
#
# #metrics {"StartTime": 1616930378.5434792, "EndTime": 1616930378.5434942, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 22.48806583180147, "count": 1, "min": 22.48806583180147, "max": 22.48806583180147}}}
#
# #metrics {"StartTime": 1616930378.543555, "EndTime": 1616930378.5435724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 77.70585841758579, "count": 1, "min": 77.70585841758579, "max": 77.70585841758579}}}
#
# #metrics {"StartTime": 1616930378.5436301, "EndTime": 1616930378.5436468, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 96.17848594515931, "count": 1, "min": 96.17848594515931, "max": 96.17848594515931}}}
#
# #metrics {"StartTime": 1616930378.5437043, "EndTime": 1616930378.5437217, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 78.9277224073223, "count": 1, "min": 78.9277224073223, "max": 78.9277224073223}}}
#
# #metrics {"StartTime": 1616930378.543759, "EndTime": 1616930378.5437734, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 91.29005821078431, "count": 1, "min": 91.29005821078431, "max": 91.29005821078431}}}
#
# #metrics {"StartTime": 1616930378.5438275, "EndTime": 1616930378.54384, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 45.33544802198223, "count": 1, "min": 45.33544802198223, "max": 45.33544802198223}}}
#
# #metrics {"StartTime": 1616930378.543871, "EndTime": 1616930378.5438793, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 51.18402458639706, "count": 1, "min": 51.18402458639706, "max": 51.18402458639706}}}
#
# #metrics {"StartTime": 1616930378.5439186, "EndTime": 1616930378.5439339, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 50.75692210477941, "count": 1, "min": 50.75692210477941, "max": 50.75692210477941}}}
#
# #metrics {"StartTime": 1616930378.5439763, "EndTime": 1616930378.5439918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 49.457256242340684, "count": 1, "min": 49.457256242340684, "max": 49.457256242340684}}}
#
# #metrics {"StartTime": 1616930378.544046, "EndTime": 1616930378.544061, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 129.08069565716912, "count": 1, "min": 129.08069565716912, "max": 129.08069565716912}}}
#
# #metrics {"StartTime": 1616930378.544117, "EndTime": 1616930378.5441356, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 133.11318550857843, "count": 1, "min": 133.11318550857843, "max": 133.11318550857843}}}
#
# #metrics {"StartTime": 1616930378.544193, "EndTime": 1616930378.544211, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 133.72300091911765, "count": 1, "min": 133.72300091911765, "max": 133.72300091911765}}}
#
# #metrics {"StartTime": 1616930378.5442672, "EndTime": 1616930378.5442855, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 126.74701765471814, "count": 1, "min": 126.74701765471814, "max": 126.74701765471814}}}
#
# #metrics {"StartTime": 1616930378.544341, "EndTime": 1616930378.544359, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 160.47667738970588, "count": 1, "min": 160.47667738970588, "max": 160.47667738970588}}}
#
# #metrics {"StartTime": 1616930378.5444233, "EndTime": 1616930378.5444417, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 141.84482230392157, "count": 1, "min": 141.84482230392157, "max": 141.84482230392157}}}
#
# #metrics {"StartTime": 1616930378.544496, "EndTime": 1616930378.544514, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 146.51439472273285, "count": 1, "min": 146.51439472273285, "max": 146.51439472273285}}}
#
# #metrics {"StartTime": 1616930378.5445702, "EndTime": 1616930378.5445867, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 155.94987457873773, "count": 1, "min": 155.94987457873773, "max": 155.94987457873773}}}
#
# [03/28/2021 11:19:38 INFO 140028512040768] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=80.95998008578431
# [03/28/2021 11:19:38 INFO 140028512040768] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=21.69844803155637
# [03/28/2021 11:19:38 INFO 140028512040768] Epoch 0: Loss improved. Updating best model
# [03/28/2021 11:19:38 INFO 140028512040768] Saving model for epoch: 0
# [03/28/2021 11:19:38 INFO 140028512040768] Saved checkpoint to "/tmp/tmpfdqpr_fz/mx-mod-0000.params"
# [03/28/2021 11:19:38 INFO 140028512040768] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1616930378.0137537, "EndTime": 1616930378.5559847, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 942.0, "count": 1, "min": 942, "max": 942}, "Total Batches Seen": {"sum": 31.0, "count": 1, "min": 31, "max": 31}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 15.0, "count": 1, "min": 15, "max": 15}}}
#
# [03/28/2021 11:19:38 INFO 140028512040768] #throughput_metric: host=algo-1, train throughput=838.919063389897 records/second
# #metrics {"StartTime": 1616930378.9605927, "EndTime": 1616930378.9606478, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.5176546105316707, "count": 1, "min": 0.5176546105316707, "max": 0.5176546105316707}}}
#
# #metrics {"StartTime": 1616930378.9607236, "EndTime": 1616930378.9607403, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.5518822861569268, "count": 1, "min": 0.5518822861569268, "max": 0.5518822861569268}}}
#
# #metrics {"StartTime": 1616930378.960798, "EndTime": 1616930378.9608154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.6205983310937881, "count": 1, "min": 0.6205983310937881, "max": 0.6205983310937881}}}
#
# #metrics {"StartTime": 1616930378.9608583, "EndTime": 1616930378.9608684, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.5998216761010033, "count": 1, "min": 0.5998216761010033, "max": 0.5998216761010033}}}
#
# #metrics {"StartTime": 1616930378.9609203, "EndTime": 1616930378.9609349, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.3713543287345341, "count": 1, "min": 0.3713543287345341, "max": 0.3713543287345341}}}
#
# #metrics {"StartTime": 1616930378.9609935, "EndTime": 1616930378.9610095, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.40196870054517475, "count": 1, "min": 0.40196870054517475, "max": 0.40196870054517475}}}
#
# #metrics {"StartTime": 1616930378.9610684, "EndTime": 1616930378.9610846, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.36066584821258274, "count": 1, "min": 0.36066584821258274, "max": 0.36066584821258274}}}
#
# #metrics {"StartTime": 1616930378.9611475, "EndTime": 1616930378.9611645, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.3634227929370744, "count": 1, "min": 0.3634227929370744, "max": 0.3634227929370744}}}
#
# #metrics {"StartTime": 1616930378.9612212, "EndTime": 1616930378.9612362, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.5674604816096169, "count": 1, "min": 0.5674604816096169, "max": 0.5674604816096169}}}
#
# #metrics {"StartTime": 1616930378.9612923, "EndTime": 1616930378.96131, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.47344650647469927, "count": 1, "min": 0.47344650647469927, "max": 0.47344650647469927}}}
#
# #metrics {"StartTime": 1616930378.9613657, "EndTime": 1616930378.961383, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.6018118155854089, "count": 1, "min": 0.6018118155854089, "max": 0.6018118155854089}}}
#
# #metrics {"StartTime": 1616930378.9614375, "EndTime": 1616930378.961454, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 0.6225737759045192, "count": 1, "min": 0.6225737759045192, "max": 0.6225737759045192}}}
#
# #metrics {"StartTime": 1616930378.9615126, "EndTime": 1616930378.9615285, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.3861394322344235, "count": 1, "min": 0.3861394322344235, "max": 0.3861394322344235}}}
#
# #metrics {"StartTime": 1616930378.9615877, "EndTime": 1616930378.9616055, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.3659241593309811, "count": 1, "min": 0.3659241593309811, "max": 0.3659241593309811}}}
#
# #metrics {"StartTime": 1616930378.9616647, "EndTime": 1616930378.9616807, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.3754237400633948, "count": 1, "min": 0.3754237400633948, "max": 0.3754237400633948}}}
#
# #metrics {"StartTime": 1616930378.9617352, "EndTime": 1616930378.9617467, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.3782113322189876, "count": 1, "min": 0.3782113322189876, "max": 0.3782113322189876}}}
#
# #metrics {"StartTime": 1616930378.961808, "EndTime": 1616930378.9618251, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.5400914411459651, "count": 1, "min": 0.5400914411459651, "max": 0.5400914411459651}}}
#
# #metrics {"StartTime": 1616930378.9618807, "EndTime": 1616930378.961898, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.5987598864095551, "count": 1, "min": 0.5987598864095551, "max": 0.5987598864095551}}}
#
# #metrics {"StartTime": 1616930378.961953, "EndTime": 1616930378.9619703, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 0.525893720132964, "count": 1, "min": 0.525893720132964, "max": 0.525893720132964}}}
#
# #metrics {"StartTime": 1616930378.9620252, "EndTime": 1616930378.9620407, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.5694302554641452, "count": 1, "min": 0.5694302554641452, "max": 0.5694302554641452}}}
#
# #metrics {"StartTime": 1616930378.9621015, "EndTime": 1616930378.962119, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.47212148351328714, "count": 1, "min": 0.47212148351328714, "max": 0.47212148351328714}}}
#
# #metrics {"StartTime": 1616930378.9621747, "EndTime": 1616930378.9621909, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.477386118045875, "count": 1, "min": 0.477386118045875, "max": 0.477386118045875}}}
#
# #metrics {"StartTime": 1616930378.962271, "EndTime": 1616930378.962289, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.47081637382507324, "count": 1, "min": 0.47081637382507324, "max": 0.47081637382507324}}}
#
# #metrics {"StartTime": 1616930378.9623444, "EndTime": 1616930378.9623601, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.47268357447215487, "count": 1, "min": 0.47268357447215487, "max": 0.47268357447215487}}}
#
# #metrics {"StartTime": 1616930378.9624145, "EndTime": 1616930378.9624307, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9491097501346043, "count": 1, "min": 0.9491097501346043, "max": 0.9491097501346043}}}
#
# #metrics {"StartTime": 1616930378.9624846, "EndTime": 1616930378.9625008, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9387565021003995, "count": 1, "min": 0.9387565021003995, "max": 0.9387565021003995}}}
#
# #metrics {"StartTime": 1616930378.9625542, "EndTime": 1616930378.9625707, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 0.9459131487778255, "count": 1, "min": 0.9459131487778255, "max": 0.9459131487778255}}}
#
# #metrics {"StartTime": 1616930378.9626312, "EndTime": 1616930378.9626482, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 0.9164817120347705, "count": 1, "min": 0.9164817120347705, "max": 0.9164817120347705}}}
#
# #metrics {"StartTime": 1616930378.9627085, "EndTime": 1616930378.9627242, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.0019333958625793, "count": 1, "min": 1.0019333958625793, "max": 1.0019333958625793}}}
#
# #metrics {"StartTime": 1616930378.962775, "EndTime": 1616930378.9627926, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9911021015473774, "count": 1, "min": 0.9911021015473774, "max": 0.9911021015473774}}}
#
# #metrics {"StartTime": 1616930378.9628592, "EndTime": 1616930378.9628766, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.9871919793742043, "count": 1, "min": 0.9871919793742043, "max": 0.9871919793742043}}}
#
# #metrics {"StartTime": 1616930378.9629302, "EndTime": 1616930378.9629412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.0077461004257202, "count": 1, "min": 1.0077461004257202, "max": 1.0077461004257202}}}
#
# [03/28/2021 11:19:38 INFO 140028512040768] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.5176546105316707
# #metrics {"StartTime": 1616930379.0346816, "EndTime": 1616930379.0347672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 63.518207624846816, "count": 1, "min": 63.518207624846816, "max": 63.518207624846816}}}
#
# #metrics {"StartTime": 1616930379.0348656, "EndTime": 1616930379.034887, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 69.11155311734069, "count": 1, "min": 69.11155311734069, "max": 69.11155311734069}}}
#
# #metrics {"StartTime": 1616930379.0349514, "EndTime": 1616930379.0349693, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 75.38654880897671, "count": 1, "min": 75.38654880897671, "max": 75.38654880897671}}}
#
# #metrics {"StartTime": 1616930379.0350296, "EndTime": 1616930379.0350475, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 72.53196806066177, "count": 1, "min": 72.53196806066177, "max": 72.53196806066177}}}
#
# #metrics {"StartTime": 1616930379.035108, "EndTime": 1616930379.0351262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 40.10551303040747, "count": 1, "min": 40.10551303040747, "max": 40.10551303040747}}}
#
# #metrics {"StartTime": 1616930379.0351846, "EndTime": 1616930379.0352023, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 36.66613290824142, "count": 1, "min": 36.66613290824142, "max": 36.66613290824142}}}
#
# #metrics {"StartTime": 1616930379.0352576, "EndTime": 1616930379.0352743, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 40.26622218711704, "count": 1, "min": 40.26622218711704, "max": 40.26622218711704}}}
#
# #metrics {"StartTime": 1616930379.0353308, "EndTime": 1616930379.035348, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 36.598015280330884, "count": 1, "min": 36.598015280330884, "max": 36.598015280330884}}}
#
# #metrics {"StartTime": 1616930379.0354028, "EndTime": 1616930379.0354197, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 68.43168370863971, "count": 1, "min": 68.43168370863971, "max": 68.43168370863971}}}
#
# #metrics {"StartTime": 1616930379.0354745, "EndTime": 1616930379.035491, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 52.39769909428615, "count": 1, "min": 52.39769909428615, "max": 52.39769909428615}}}
#
# #metrics {"StartTime": 1616930379.035564, "EndTime": 1616930379.0355806, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 73.0404914407169, "count": 1, "min": 73.0404914407169, "max": 73.0404914407169}}}
#
# #metrics {"StartTime": 1616930379.0356336, "EndTime": 1616930379.0356514, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 79.99303720511642, "count": 1, "min": 79.99303720511642, "max": 79.99303720511642}}}
#
# #metrics {"StartTime": 1616930379.035707, "EndTime": 1616930379.0357232, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 36.71974331724878, "count": 1, "min": 36.71974331724878, "max": 36.71974331724878}}}
#
# #metrics {"StartTime": 1616930379.035779, "EndTime": 1616930379.0357957, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 40.526021321614586, "count": 1, "min": 40.526021321614586, "max": 40.526021321614586}}}
#
# #metrics {"StartTime": 1616930379.035851, "EndTime": 1616930379.0358684, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 39.38000129250919, "count": 1, "min": 39.38000129250919, "max": 39.38000129250919}}}
#
# #metrics {"StartTime": 1616930379.035925, "EndTime": 1616930379.035941, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 36.161631864659924, "count": 1, "min": 36.161631864659924, "max": 36.161631864659924}}}
#
# #metrics {"StartTime": 1616930379.0359955, "EndTime": 1616930379.036012, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 63.31889313342524, "count": 1, "min": 63.31889313342524, "max": 63.31889313342524}}}
#
# #metrics {"StartTime": 1616930379.036064, "EndTime": 1616930379.0360806, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 74.31149710860907, "count": 1, "min": 74.31149710860907, "max": 74.31149710860907}}}
#
# #metrics {"StartTime": 1616930379.0361345, "EndTime": 1616930379.036151, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 64.77428481158088, "count": 1, "min": 64.77428481158088, "max": 64.77428481158088}}}
#
# #metrics {"StartTime": 1616930379.0362022, "EndTime": 1616930379.0362163, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 71.81614535462623, "count": 1, "min": 71.81614535462623, "max": 71.81614535462623}}}
#
# #metrics {"StartTime": 1616930379.0362713, "EndTime": 1616930379.0363045, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 46.80215274586397, "count": 1, "min": 46.80215274586397, "max": 46.80215274586397}}}
#
# #metrics {"StartTime": 1616930379.036362, "EndTime": 1616930379.0363796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 49.268073586856616, "count": 1, "min": 49.268073586856616, "max": 49.268073586856616}}}
#
# #metrics {"StartTime": 1616930379.0364342, "EndTime": 1616930379.036451, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 48.8560791015625, "count": 1, "min": 48.8560791015625, "max": 48.8560791015625}}}
#
# #metrics {"StartTime": 1616930379.036506, "EndTime": 1616930379.0365229, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 48.57815372242647, "count": 1, "min": 48.57815372242647, "max": 48.57815372242647}}}
#
# #metrics {"StartTime": 1616930379.0365775, "EndTime": 1616930379.0365942, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 132.02610868566177, "count": 1, "min": 132.02610868566177, "max": 132.02610868566177}}}
#
# #metrics {"StartTime": 1616930379.0366483, "EndTime": 1616930379.0366647, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 127.25984221813725, "count": 1, "min": 127.25984221813725, "max": 127.25984221813725}}}
#
# #metrics {"StartTime": 1616930379.0367184, "EndTime": 1616930379.0367346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 129.49669692095588, "count": 1, "min": 129.49669692095588, "max": 129.49669692095588}}}
#
# #metrics {"StartTime": 1616930379.0367868, "EndTime": 1616930379.0368028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 128.70515471813727, "count": 1, "min": 128.70515471813727, "max": 128.70515471813727}}}
#
# #metrics {"StartTime": 1616930379.0368547, "EndTime": 1616930379.036871, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 132.2457825903799, "count": 1, "min": 132.2457825903799, "max": 132.2457825903799}}}
#
# #metrics {"StartTime": 1616930379.0369236, "EndTime": 1616930379.036943, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 123.88744159773285, "count": 1, "min": 123.88744159773285, "max": 123.88744159773285}}}
#
# ...
#
# #metrics {"StartTime": 1616930380.717696, "EndTime": 1616930380.717721, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 0.9775776224476951, "count": 1, "min": 0.9775776224476951, "max": 0.9775776224476951}}}
#
# #metrics {"StartTime": 1616930380.717921, "EndTime": 1616930380.7179475, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.9824522861412593, "count": 1, "min": 0.9824522861412593, "max": 0.9824522861412593}}}
#
# #metrics {"StartTime": 1616930380.7181513, "EndTime": 1616930380.7181756, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.9798375112669808, "count": 1, "min": 0.9798375112669808, "max": 0.9798375112669808}}}
#
# #metrics {"StartTime": 1616930380.7183955, "EndTime": 1616930380.7184215, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.9829081892967224, "count": 1, "min": 0.9829081892967224, "max": 0.9829081892967224}}}
#
# [03/28/2021 11:19:40 INFO 140028512040768] #quality_metric: host=algo-1, epoch=4, train mse_objective <loss>=0.36309103667736053
# #metrics {"StartTime": 1616930380.786602, "EndTime": 1616930380.7866554, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 39.29164153454351, "count": 1, "min": 39.29164153454351, "max": 39.29164153454351}}}
#
# #metrics {"StartTime": 1616930380.786736, "EndTime": 1616930380.7867498, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 41.6670867321538, "count": 1, "min": 41.6670867321538, "max": 41.6670867321538}}}
#
# #metrics {"StartTime": 1616930380.7867868, "EndTime": 1616930380.7867966, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 44.51085229013481, "count": 1, "min": 44.51085229013481, "max": 44.51085229013481}}}
#
# #metrics {"StartTime": 1616930380.7868307, "EndTime": 1616930380.7868397, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 41.63320982689951, "count": 1, "min": 41.63320982689951, "max": 41.63320982689951}}}
#
# #metrics {"StartTime": 1616930380.7868695, "EndTime": 1616930380.7868783, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 33.84152281518076, "count": 1, "min": 33.84152281518076, "max": 33.84152281518076}}}
#
# #metrics {"StartTime": 1616930380.786907, "EndTime": 1616930380.7869153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 34.279549392999385, "count": 1, "min": 34.279549392999385, "max": 34.279549392999385}}}
#
# #metrics {"StartTime": 1616930380.7869623, "EndTime": 1616930380.7869797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 33.49555759803921, "count": 1, "min": 33.49555759803921, "max": 33.49555759803921}}}
#
# #metrics {"StartTime": 1616930380.787032, "EndTime": 1616930380.7870488, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 33.005290910309434, "count": 1, "min": 33.005290910309434, "max": 33.005290910309434}}}
#
# #metrics {"StartTime": 1616930380.7871046, "EndTime": 1616930380.7871208, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 39.52565989774816, "count": 1, "min": 39.52565989774816, "max": 39.52565989774816}}}
#
# #metrics {"StartTime": 1616930380.7871716, "EndTime": 1616930380.7871861, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 34.2645814185049, "count": 1, "min": 34.2645814185049, "max": 34.2645814185049}}}
#
# #metrics {"StartTime": 1616930380.7872386, "EndTime": 1616930380.7872555, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 45.08792054419424, "count": 1, "min": 45.08792054419424, "max": 45.08792054419424}}}
#
# #metrics {"StartTime": 1616930380.78731, "EndTime": 1616930380.7873268, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 45.6641570446538, "count": 1, "min": 45.6641570446538, "max": 45.6641570446538}}}
#
# #metrics {"StartTime": 1616930380.7873793, "EndTime": 1616930380.7873938, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 34.961617264093135, "count": 1, "min": 34.961617264093135, "max": 34.961617264093135}}}
#
# #metrics {"StartTime": 1616930380.7874486, "EndTime": 1616930380.787466, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 32.11845487706802, "count": 1, "min": 32.11845487706802, "max": 32.11845487706802}}}
#
# #metrics {"StartTime": 1616930380.7875195, "EndTime": 1616930380.787535, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 33.59976495481005, "count": 1, "min": 33.59976495481005, "max": 33.59976495481005}}}
#
# #metrics {"StartTime": 1616930380.7875917, "EndTime": 1616930380.787609, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 33.31870763442095, "count": 1, "min": 33.31870763442095, "max": 33.31870763442095}}}
#
# #metrics {"StartTime": 1616930380.7876668, "EndTime": 1616930380.787683, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 51.65259267769608, "count": 1, "min": 51.65259267769608, "max": 51.65259267769608}}}
#
# #metrics {"StartTime": 1616930380.7877402, "EndTime": 1616930380.7877576, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 55.09014533547794, "count": 1, "min": 55.09014533547794, "max": 55.09014533547794}}}
#
# #metrics {"StartTime": 1616930380.787814, "EndTime": 1616930380.7878308, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 50.8673765893076, "count": 1, "min": 50.8673765893076, "max": 50.8673765893076}}}
#
# #metrics {"StartTime": 1616930380.787886, "EndTime": 1616930380.787902, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 52.136127546721816, "count": 1, "min": 52.136127546721816, "max": 52.136127546721816}}}
#
# #metrics {"StartTime": 1616930380.7879596, "EndTime": 1616930380.7879767, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 53.877829159007355, "count": 1, "min": 53.877829159007355, "max": 53.877829159007355}}}
#
# #metrics {"StartTime": 1616930380.788032, "EndTime": 1616930380.7880495, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 53.04123104319853, "count": 1, "min": 53.04123104319853, "max": 53.04123104319853}}}
#
# #metrics {"StartTime": 1616930380.7881064, "EndTime": 1616930380.788124, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 53.87796080346201, "count": 1, "min": 53.87796080346201, "max": 53.87796080346201}}}
#
# #metrics {"StartTime": 1616930380.7881794, "EndTime": 1616930380.788198, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 53.1971986060049, "count": 1, "min": 53.1971986060049, "max": 53.1971986060049}}}
#
# #metrics {"StartTime": 1616930380.788257, "EndTime": 1616930380.7882736, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 131.9057808670343, "count": 1, "min": 131.9057808670343, "max": 131.9057808670343}}}
#
# #metrics {"StartTime": 1616930380.7883232, "EndTime": 1616930380.7883403, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 131.52062748927696, "count": 1, "min": 131.52062748927696, "max": 131.52062748927696}}}
#
# #metrics {"StartTime": 1616930380.7883983, "EndTime": 1616930380.7884152, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 131.50060795802696, "count": 1, "min": 131.50060795802696, "max": 131.50060795802696}}}
#
# #metrics {"StartTime": 1616930380.7884636, "EndTime": 1616930380.788478, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 131.43115234375, "count": 1, "min": 131.43115234375, "max": 131.43115234375}}}
#
# #metrics {"StartTime": 1616930380.7885325, "EndTime": 1616930380.7885501, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 135.9484193091299, "count": 1, "min": 135.9484193091299, "max": 135.9484193091299}}}
#
# #metrics {"StartTime": 1616930380.788605, "EndTime": 1616930380.7886221, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 135.2569699754902, "count": 1, "min": 135.2569699754902, "max": 135.2569699754902}}}
#
# #metrics {"StartTime": 1616930380.7886772, "EndTime": 1616930380.788695, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 134.5074151731005, "count": 1, "min": 134.5074151731005, "max": 134.5074151731005}}}
#
# #metrics {"StartTime": 1616930380.7887552, "EndTime": 1616930380.788773, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 134.11312327665442, "count": 1, "min": 134.11312327665442, "max": 134.11312327665442}}}
#
# [03/28/2021 11:19:40 INFO 140028512040768] #quality_metric: host=algo-1, epoch=4, validation mse_objective <loss>=39.29164153454351
# [03/28/2021 11:19:40 INFO 140028512040768] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=mse_objective, value=32.11845487706802
# [03/28/2021 11:19:40 INFO 140028512040768] Saving model for epoch: 4
# [03/28/2021 11:19:40 INFO 140028512040768] Saved checkpoint to "/tmp/tmpfuwheqzc/mx-mod-0000.params"
# [03/28/2021 11:19:40 INFO 140028512040768] Early stop condition met. Stopping training.
# [03/28/2021 11:19:40 INFO 140028512040768] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1616930380.179309, "EndTime": 1616930380.7957237, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2762.0, "count": 1, "min": 2762, "max": 2762}, "Total Batches Seen": {"sum": 91.0, "count": 1, "min": 91, "max": 91}, "Max Records Seen Between Resets": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Max Batches Seen Between Resets": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 455.0, "count": 1, "min": 455, "max": 455}, "Number of Batches Since Last Reset": {"sum": 15.0, "count": 1, "min": 15, "max": 15}}}
#
# [03/28/2021 11:19:40 INFO 140028512040768] #throughput_metric: host=algo-1, train throughput=737.941251872976 records/second
# [03/28/2021 11:19:40 WARNING 140028512040768] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [03/28/2021 11:19:40 WARNING 140028512040768] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [03/28/2021 11:19:40 INFO 140028512040768] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=mse_objective, value=32.11845487706802
# [03/28/2021 11:19:40 INFO 140028512040768] #validation_score (algo-1) : ('mse_objective', 21.69844803155637)
# [03/28/2021 11:19:40 INFO 140028512040768] #validation_score (algo-1) : ('mse', 21.69844803155637)
# [03/28/2021 11:19:40 INFO 140028512040768] #validation_score (algo-1) : ('absolute_loss', 3.769265268363205)
# [03/28/2021 11:19:40 INFO 140028512040768] #quality_metric: host=algo-1, validation mse_objective <loss>=21.69844803155637
# [03/28/2021 11:19:40 INFO 140028512040768] #quality_metric: host=algo-1, validation mse <loss>=21.69844803155637
# [03/28/2021 11:19:40 INFO 140028512040768] #quality_metric: host=algo-1, validation absolute_loss <loss>=3.769265268363205
# [03/28/2021 11:19:40 INFO 140028512040768] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.01, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [03/28/2021 11:19:40 INFO 140028512040768] Saved checkpoint to "/tmp/tmphclqt0us/mx-mod-0000.params"
# [03/28/2021 11:19:40 INFO 140028512040768] Test data is not provided.
# #metrics {"StartTime": 1616930377.6827915, "EndTime": 1616930380.895817, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 320.00112533569336, "count": 1, "min": 320.00112533569336, "max": 320.00112533569336}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 2.4557113647460938, "count": 6, "min": 0.202178955078125, "max": 1.1665821075439453}, "update.time": {"sum": 2744.0009117126465, "count": 5, "min": 485.69202423095703, "max": 613.121509552002}, "finalize.time": {"sum": 92.9417610168457, "count": 1, "min": 92.9417610168457, "max": 92.9417610168457}, "setuptime": {"sum": 33.01739692687988, "count": 1, "min": 33.01739692687988, "max": 33.01739692687988}, "totaltime": {"sum": 3444.0338611602783, "count": 1, "min": 3444.0338611602783, "max": 3444.0338611602783}}}
# 2021-03-28 11:20:13 Uploading - Uploading generated training model
# 2021-03-28 11:20:13 Completed - Training job completed
# ProfilerReport-1616930168: NoIssuesFound
# Training seconds: 68
# Billable seconds: 68

# %% [markdown]
# 2. Once training is complete, the model is copied automatically to S3.
# 3. Looking at the output location in our S3 bucket, we see the model artifact:

# %%
# command is working in studio but not working locally

#%%bash -s "$ll_estimator.output_path"
#aws s3 ls --recursive $1

# %% [markdown]
# ## 5.Deploying a model
# 1.It's good practice to create identifiable and unique endpoint names. We could also
# let SageMaker create one for us during deployment:

# %%
from time import strftime, gmtime
timestamp = strftime('%d-%H-%M-%S', gmtime())

endpoint_name = 'linear-learner-demo-'+timestamp
print(endpoint_name)
# Out:
# linear-learner-demo-28-11-21-21

# %% [markdown]
# 2. We deploy the model using the deploy() API.

# %%
ll_predictor = ll_estimator.deploy(
                endpoint_name=endpoint_name, 
                initial_instance_count=1, 
                instance_type='ml.t2.medium')
# Out:
# -----------------!

# %% [markdown]
# 3. A few minutes later, the endpoint is in service. We can use the predict() API
# to send it a CSV sample for prediction. We set content type and serialization
# accordingly: built-in functions are available, and we use them as is:

# %%
test_sample = '0.00632,18.00,2.310,0,0.5380,6.5750,65.20,4.0900,1,296.0,15.30,4.98'

#ll_predictor.content_type = 'text/csv'
ll_predictor.serializer = sagemaker.serializers.CSVSerializer()
ll_predictor.deserializer = sagemaker.deserializers.CSVDeserializer()

response = ll_predictor.predict(test_sample)
print(response)
# Out:
# [['31.62579345703125']]

# %% [markdown]
# 4. We can also predict multiple samples at a time:

# %%
test_samples = ['0.00632,18.00,2.310,0,0.5380,6.5750,65.20,4.0900,1,296.0,15.30,4.98',
                '0.02731,0.00,7.070,0,0.4690,6.4210,78.90,4.9671,2,242.0,17.80,9.14']

response = ll_predictor.predict(test_samples)
print(response)
# Out:
# [['31.62579345703125'], ['24.375823974609375']]

# %%
# another way to predict
runtime = boto3.Session().client(service_name='runtime.sagemaker') 

response = runtime.invoke_endpoint(EndpointName=endpoint_name, 
                                  ContentType='text/csv', 
                                  Body=test_sample)

print(response['Body'].read())
# Out:
# b'{"predictions": [{"score": 31.62579345703125}]}'

# %% [markdown]
# ## Cleaning up

# %%
ll_predictor.delete_endpoint()

# %% [markdown]
# Note:
#
# we didn't delete the data stored in s3, if you don't want to be charged, delete it as well.
#
# Also we are going to use same data in next example, better not to delete it for now.
