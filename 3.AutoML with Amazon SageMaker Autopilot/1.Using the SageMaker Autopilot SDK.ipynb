# %% [markdown]
# ### Using the SageMaker Autopilot SDK
# The Amazon SageMaker SDK includes a simple API for SageMaker Autopilot. You can find its documentation at https://sagemaker.readthedocs.io/en/stable/automl.html. In this section, you'll learn how to use this API to train a model on the same dataset as in the previous section.

# %% [markdown]
# Launching a jobThe SageMaker SDK makes it extremely easy to launch an Autopilot job – just upload your data in S3, and call a single API! Let's see how:
#
# 1. First, we import the SageMaker SDK:

# %%
import sagemaker
sess = sagemaker.Session()

# %% [markdown]
# 2. Then, we download the dataset:

# %%
# link is not working

# %%sh
# wget -N https://sagemaker-sample-data-us-west-2.s3-us-west-2.amazonaws.com/autopilot/direct_marketing/bank-additional.zip
# unzip -o bank-additional.zip

# %%
# reading data from URL
import pandas as pd
url = "https://github.com/h2oai/h2o-2/raw/master/smalldata/bank-additional-full.csv"
data = pd.read_csv(url, sep=';')
#display(data.head(3))

# Randomly sample 70% of your dataframe
df = data.sample(frac=0.7)
display(df.head(3))

# saving file in current path
df.to_csv('bank-additional-full.csv')
# Out:
#        age          job   marital            education  default housing loan  \
# 28537   38   technician  divorced    university.degree       no      no   no
# 3377    47  blue-collar   married              unknown  unknown     yes   no
# 29349   26   technician    single  professional.course       no     yes   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 28537   cellular   apr         wed  ...         2    999         2
# 3377   telephone   may         thu  ...         1    999         0
# 29349  telephone   apr         fri  ...         2    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 28537      failure         -1.8          93.075          -47.1      1.415
# 3377   nonexistent          1.1          93.994          -36.4      4.860
# 29349  nonexistent         -1.8          93.075          -47.1      1.405
#
#        nr.employed   y
# 28537       5099.1  no
# 3377        5191.0  no
# 29349       5099.1  no
#
# [3 rows x 21 columns]

# %% [markdown]
# 3. Next, we upload the dataset to S3:

# %%
bucket = sess.default_bucket()
prefix = 'sagemaker/DEMO-automl-dm'

# %%
s3_input_data = sess.upload_data(path="./bank-additional-full.csv",
                                 key_prefix = prefix + 'input')
# locaion in bucket now
# s3://sagemaker-us-east-1-603012210694/sagemaker/DEMO-automl-dminput/

# %%
#One extra step here:
#for some reason get_execution_role() don't work locally for that we have few other ways to do that
# Code link: https://github.com/aws/sagemaker-python-sdk/issues/300 

import boto3
region = boto3.Session().region_name

def resolve_sm_role():
    client = boto3.client('iam', region_name=region)
    response_roles = client.list_roles(
        PathPrefix='/',
        # Marker='string',
        MaxItems=999
    )
    for role in response_roles['Roles']:
        if role['RoleName'].startswith('AmazonSageMaker-ExecutionRole-'):
            #print('Resolved SageMaker IAM Role to: ' + str(role))
            return role['Arn']
    raise Exception('Could not resolve what should be the SageMaker role to be used')

role = resolve_sm_role()
#print(role)

# %% [markdown]
# 4. We then configure the AutoML job, which only takes one line of code. We define the target attribute (remember, that column is named y), and where to store training artifacts. Optionally, we can also set a maximum run time for the job, a maximum run time per job, or reduce the number of candidate models that will be tuned. Please note that restricting the job's duration too much is likely to impact its accuracy. For development purposes, this isn't a problem, so let's cap our job at one hour, or 250 tuning jobs (whichever limit it hits first):

# %%
from sagemaker.automl.automl import AutoML
auto_ml_job = AutoML(role = role,#sagemaker.get_execution_role(),
                     sagemaker_session = sess,
                     target_attribute_name = 'y',
                     output_path = 's3://{}/{}/output'.format(bucket,prefix),
                     max_runtime_per_training_job_in_seconds = 600,
                     max_candidates = 5,#250,
                     total_job_runtime_in_seconds = 3600)

# %% [markdown]
# 5. Next, we launch the Autopilot job, passing it the location of the training set. We turn logs off (who wants to read hundreds of tuning logs?), and we set the call to non-blocking, as we'd like to query the job status in the next cells:

# %%
auto_ml_job.fit(inputs=s3_input_data, logs=False, wait=False)

# %% [markdown]
# The job starts right away. Now let's see how we can monitor its status.

# %% [markdown]
# ### Monitoring a job
# While the job is running, we can use the describe_auto_ml_job() API to monitor its progress:
#
# 1. For example, the following code will check the job's status every 30 seconds until the data analysis step completes:

# %%
from time import sleep
job = auto_ml_job.describe_auto_ml_job()
job_status = job['AutoMLJobStatus']
job_sec_status = job['AutoMLJobSecondaryStatus']

# %%
if job_status not in ('Stopped', 'Failed'):
    while job_status in ('InProgress') and job_sec_status    in ('AnalyzingData'):
        sleep(30)
        job = auto_ml_job.describe_auto_ml_job()
        job_status = job['AutoMLJobStatus']
        job_sec_status = job['AutoMLJobSecondaryStatus']
        print (job_status, job_sec_status)
# Out:
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress AnalyzingData
# InProgress FeatureEngineering

# %% [markdown]
# 2. Once the data analysis is complete, the two auto-generated notebooks are available. We can find their location using the same API:

# %%
job = auto_ml_job.describe_auto_ml_job()
job_candidate_notebook = job['AutoMLJobArtifacts']['CandidateDefinitionNotebookLocation']
job_data_notebook = job['AutoMLJobArtifacts']['DataExplorationNotebookLocation']
print(job_candidate_notebook)
print()
print(job_data_notebook)
# Out:
# s3://sagemaker-us-east-1-603012210694/sagemaker/DEMO-automl-dm/output/automl-2021-03-11-15-18-06-196/sagemaker-automl-candidates/pr-1-a51af9647a40452f929f64b8aa8a01056a2e1ab7043e4653abefbd0fdd/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb
#
# s3://sagemaker-us-east-1-603012210694/sagemaker/DEMO-automl-dm/output/automl-2021-03-11-15-18-06-196/sagemaker-automl-candidates/pr-1-a51af9647a40452f929f64b8aa8a01056a2e1ab7043e4653abefbd0fdd/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb

# %% [markdown]
# 3. Using the AWS CLI, we can copy the two notebooks locally. We'll take a look at them later in this chapter:

# %%
# not working

# %%sh -s $job_candidate_notebook $job_data_notebook
aws s3 cp $1 .
aws s3 cp $2 .

# %% [markdown]
# 4. While the feature engineering runs, we can wait for completion using the same code snippet as the preceding, looping while job_sec_status is equal to FeatureEngineering.

# %% [markdown]
# 5. Once the feature engineering is complete, the model tuning starts. While it's running, we can use the Amazon SageMaker Experiments SDK to keep track of jobs. We'll cover SageMaker Experiments in detail in a later chapter, but here, the code is simple enough to give you a sneak peek! All it takes is to pass the experiment name to the ExperimentAnalytics object. Then, we can retrieve information on all tuning jobs so far in a pandas DataFrame. From then on, it's business as usual, and we can easily display the number of jobs that have already run, and the top 5 jobs so far:

# %%
import pandas as pd
from sagemaker.analytics import ExperimentAnalytics

exp = ExperimentAnalytics(sagemaker_session=sess,
                          experiment_name=job['AutoMLJobName']+'-aws-auto-ml-job')
df = exp.dataframe()
print("Number of jobs: ", len(df))

df = pd.concat([df['ObjectiveMetric - Max'],
                df.drop(['ObjectiveMetric - Max'], axis=1)], axis=1)

df.sort_values('ObjectiveMetric - Max', ascending=0)[:5]
# Out:
# Number of jobs:  5
#    ObjectiveMetric - Max                                 TrialComponentName  \
# 1                0.76126  tuning-job-1-46dfc77b76b643acbc-002-3a820be7-a...
# 0                0.71679  tuning-job-1-46dfc77b76b643acbc-001-ba22ca75-a...
# 2                    NaN  automl-202-dpp0-csv-1-a68308d3550443d59a939816...
# 3                    NaN  automl-202-dpp0-1-24ee556126e04ed1a1359ecbf194...
# 4                    NaN  db-1-83b4cfe79c0a4060ad5512f53c014c22ea7dd12aa...
#
#                                          DisplayName  \
# 1  tuning-job-1-46dfc77b76b643acbc-002-3a820be7-a...
# 0  tuning-job-1-46dfc77b76b643acbc-001-ba22ca75-a...
# 2  automl-202-dpp0-csv-1-a68308d3550443d59a939816...
# 3  automl-202-dpp0-1-24ee556126e04ed1a1359ecbf194...
# 4  db-1-83b4cfe79c0a4060ad5512f53c014c22ea7dd12aa...
#
#                                            SourceArn  \
# 1  arn:aws:sagemaker:us-east-1:603012210694:train...
# 0  arn:aws:sagemaker:us-east-1:603012210694:train...
# 2  arn:aws:sagemaker:us-east-1:603012210694:trans...
# 3  arn:aws:sagemaker:us-east-1:603012210694:train...
# 4  arn:aws:sagemaker:us-east-1:603012210694:proce...
#
#                                   SageMaker.ImageUri  SageMaker.InstanceCount  \
# 1  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...                      1.0
# 0  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...                      1.0
# 2                                                NaN                      1.0
# 3  683313688378.dkr.ecr.us-east-1.amazonaws.com/s...                      1.0
# 4                                                NaN                      1.0
#
#   SageMaker.InstanceType  SageMaker.VolumeSizeInGB _tuning_objective_metric  \
# 1          ml.m5.4xlarge                      50.0            validation:f1
# 0          ml.m5.4xlarge                      50.0            validation:f1
# 2          ml.m5.4xlarge                       NaN                      NaN
# 3          ml.m5.4xlarge                      50.0                      NaN
# 4          ml.m5.2xlarge                     250.0                      NaN
#
#      alpha  ...    code - MediaType  \
# 1  0.00001  ...                 NaN
# 0  0.03380  ...                 NaN
# 2      NaN  ...                 NaN
# 3      NaN  ...  application/x-code
# 4      NaN  ...                 NaN
#
#                                         code - Value  input_channel_mode  \
# 1                                                NaN                 NaN
# 0                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3  s3://sagemaker-us-east-1-603012210694/sagemake...                 NaN
# 4                                                NaN                Pipe
#
#                          job_name  label_col  max_dataset_size  \
# 1                             NaN        NaN               NaN
# 0                             NaN        NaN               NaN
# 2                             NaN        NaN               NaN
# 3                             NaN        NaN               NaN
# 4  automl-2021-03-11-15-18-06-196          y                 5
#
#    SageMaker.ImageUri - MediaType  \
# 1                             NaN
# 0                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#                           SageMaker.ImageUri - Value ds - MediaType  \
# 1                                                NaN            NaN
# 0                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4  120479346908.dkr.ecr.us-east-1.amazonaws.com/d...            NaN
#
#                                           ds - Value
# 1                                                NaN
# 0                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  s3://sagemaker-us-east-1-603012210694/sagemake...
#
# [5 rows x 78 columns]

# %% [markdown]
# 6. Once the model tuning is complete, we can very easily find the best candidate:

# %%
# error

job_best_candidate = auto_ml_job.best_candidate()
print(job_best_candidate['CandidateName'])
print(job_best_candidate['FinalAutoMLJobObjectiveMetric'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-f3b865efea1a> in <module>
#       1 # error
#       2
# ----> 3 job_best_candidate = auto_ml_job.best_candidate()
#       4 print(job_best_candidate['CandidateName'])
#       5 print(job_best_candidate['FinalAutoMLJobObjectiveMetric'])
#
# C:\Env\sagemaker\lib\site-packages\sagemaker\automl\automl.py in best_candidate(self, job_name)
#     198             self._auto_ml_job_desc = self.sagemaker_session.describe_auto_ml_job(job_name)
#     199
# --> 200         self._best_candidate = self._auto_ml_job_desc["BestCandidate"]
#     201         return self._best_candidate
#     202
#
# KeyError: 'BestCandidate'

# %% [markdown]
# Then, we can deploy and test the model using the SageMaker SDK. We've covered a lot of ground already, so let's save that for future chapters, where we'll revisit this example.

# %% [markdown]
# ### Cleaning up
# SageMaker Autopilot creates many underlying artifacts such as dataset splits, pre-processing scripts, pre-processed datasets, models, and so on. If you'd like to clean up completely, the following code snippet will do that. Of course, you could also use the AWS CLI:

# %%
import boto3
job_outputs_prefix = '{}/output/{}'.format(prefix, job['AutoMLJobName'])
s3_bucket = boto3.resource('s3').Bucket(bucket)
s3_bucket.objects.filter(Prefix=job_outputs_prefix).delete()
# Out:
# [{'ResponseMetadata': {'RequestId': '2SJA41B3388T9BNQ',
#    'HostId': 'ZoGxa+A/y2men3HndTLyXuTco0x5uH1+5K72LNdOc9b76cEhl5/l/sw46QVB+l4Xkd/rNASVF28=',
#    'HTTPStatusCode': 200,
#    'HTTPHeaders': {'x-amz-id-2': 'ZoGxa+A/y2men3HndTLyXuTco0x5uH1+5K72LNdOc9b76cEhl5/l/sw46QVB+l4Xkd/rNASVF28=',
#     'x-amz-request-id': '2SJA41B3388T9BNQ',
#     'date': 'Thu, 11 Mar 2021 11:11:33 GMT',
#     'content-type': 'application/xml',
#     'transfer-encoding': 'chunked',
#     'server': 'AmazonS3',
#     'connection': 'close'},
#    'RetryAttempts': 0},
#   'Deleted': [{'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/notebooks/sagemaker_automl/steps.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/generated_module/candidate_data_processors/dpp3.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_78.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/data-processor-models/automl-202-dpp0-1-d5da113546fa4f13925fadfee4cb9085ed94080174704/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_66.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_93.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/generated_module/setup.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/tuning/automl-202-dpp3-xgb/tuning-job-1-0c043933ef4c4d37b3-004-a22f1961/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/header/headers.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_43.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_88.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_93.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_98.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_75.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_50.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_99.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_69.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_23.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_88.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_92.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_82.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_12.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/generated_module/README.md'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_95.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_31.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_58.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_70.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_62.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_98.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_65.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_94.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_21.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_53.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/notebooks/sagemaker_automl/interactive_runner.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_49.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/generated_module/MANIFEST.in'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_94.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_3.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_95.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_14.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_7.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_71.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_71.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_73.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_91.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_6.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_60.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_88.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_71.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_57.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_87.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_1.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_21.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_21.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_46.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_62.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_25.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_39.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_92.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_21.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_72.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_86.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_87.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_88.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_63.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_85.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_46.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_88.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_29.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_38.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/tuning/automl-202-dpp3-xgb/tuning-job-1-0c043933ef4c4d37b3-002-b51d3791/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/generated_module/candidate_data_processors/dpp4.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_47.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_28.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/data-processor-models/automl-202-dpp3-1-892edc9fe320446a8443903dc17fa7e51e2e7340af704/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_27.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_84.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_94.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_5.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_95.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_39.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_87.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/validation/chunk_1.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_4.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_15.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_34.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_47.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_18.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_72.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_9.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_21.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_26.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_95.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_30.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_11.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_41.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_80.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_24.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_96.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_31.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/validation/chunk_4.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_85.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/notebooks/sagemaker_automl/config.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_87.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_97.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_15.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/generated_module/candidate_data_processors/sagemaker_serve.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_19.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/tuning/automl-202-dpp3-xgb/tuning-job-1-0c043933ef4c4d37b3-003-f821a717/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/data-processor-models/automl-202-dpp2-1-2910520f650b4eb28182bf9f406104da7fba7cdb4eb34/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_44.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_5.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/notebooks/sagemaker_automl/common.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/tuning/automl-202-dpp3-xgb/tuning-job-1-0c043933ef4c4d37b3-005-3080a32d/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_76.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_52.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/validations/output_validation'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_67.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_49.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_93.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_87.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_48.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_18.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/generated_module/candidate_data_processors/dpp1.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_54.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_22.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_3.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/validation/chunk_6.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_0.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_91.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_70.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_27.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_29.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_77.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_86.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_76.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_4.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_10.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_96.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_69.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_81.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_26.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_52.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_14.csv.out'},
# ...
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/tuning/automl-202-dpp2-ll/tuning-job-1-0c043933ef4c4d37b3-001-0cba30b9/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/data-processor-models/automl-202-dpp4-1-d0d5fdf761ac4e6b8a721c754cad594b4337f99068ef4/output/model.tar.gz'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_98.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_32.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_22.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_4.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_96.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_71.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_33.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_13.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_34.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_19.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_8.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_58.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_96.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_21.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_83.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_41.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_88.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/validation/chunk_12.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_2.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_17.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_0.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_65.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_93.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_94.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_24.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_64.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_96.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_82.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_84.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_95.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/validation/chunk_2.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_63.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_51.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_28.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_17.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_11.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/generated_module/candidate_data_processors/dpp0.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_86.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_55.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_23.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_94.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_15.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_56.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_45.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_20.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_78.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_74.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_99.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_7.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_68.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_59.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_89.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_30.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_83.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_90.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_20.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/validation/chunk_10.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_37.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_74.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_44.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/notebooks/sagemaker_automl/README.md'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_60.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/validation/chunk_16.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_25.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_67.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_40.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_35.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_16.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/validation/chunk_14.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/validation/chunk_15.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_36.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_99.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_61.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_43.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_40.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/notebooks/SageMakerAutopilotCandidateDefinitionNotebook.ipynb'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_66.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_79.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_32.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/notebooks/SageMakerAutopilotDataExplorationNotebook.ipynb'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp1/csv/train/chunk_86.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_53.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_42.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_13.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_8.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp4/rpb/train/chunk_48.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/preprocessed-data/tuning_data/train/chunk_77.csv'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/validation/chunk_4.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/sagemaker-automl-candidates/pr-1-7a9a812d63984f8d803b90a734e5407a14a8621e165c4b2e8d40991e9c/notebooks/sagemaker_automl/__init__.py'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp2/rpb/train/chunk_75.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp3/csv/train/chunk_73.csv.out'},
#    {'Key': 'sagemaker/DEMO-automl-dm/output/automl-2021-03-11-10-45-36-874/transformed-data/dpp0/csv/train/chunk_53.csv.out'}]}]
